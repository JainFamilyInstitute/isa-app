# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('quantile-results.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  index  Quartile  Age     Category Agent  Borrowing Amount  \
# 0           0      0         1   22       Income   ISA              5000
# 1           1      1         1   22      Payment   ISA              5000
# 2           2      2         1   22  Consumption   ISA              5000
# 3           3      3         1   22      Utility   ISA              5000
# 4           4      4         2   22       Income   ISA              5000
#
#    Risk Aversion  18  19      ...                 91            92  \
# 0              3 NaN NaN      ...       6.001508e+03  6.001508e+03
# 1              3 NaN NaN      ...       0.000000e+00  0.000000e+00
# 2              3 NaN NaN      ...       6.115424e+03  6.112404e+03
# 3              3 NaN NaN      ...      -5.105495e-08 -5.105374e-08
# 4              3 NaN NaN      ...       1.201656e+04  1.201656e+04
#
#              93            94            95            96            97  \
# ...

# %%
df = df.drop(['Unnamed: 0', 'index'], axis=1)
# rename columns
df.rename(columns={'Quartile':'quartile'}, inplace=True)
df.rename(columns={'Category':'variable'}, inplace=True)
df.rename(columns={'Borrowing Amount':'amount'}, inplace=True)
df.rename(columns={'Agent':'type'}, inplace=True)
df.rename(columns={'Risk Aversion':'risk'}, inplace=True)

# %%
df.head()
# Out:
#    quartile  Age     variable type  amount  risk  18  19  20  21  \
# 0         1   22       Income  ISA    5000     3 NaN NaN NaN NaN
# 1         1   22      Payment  ISA    5000     3 NaN NaN NaN NaN
# 2         1   22  Consumption  ISA    5000     3 NaN NaN NaN NaN
# 3         1   22      Utility  ISA    5000     3 NaN NaN NaN NaN
# 4         2   22       Income  ISA    5000     3 NaN NaN NaN NaN
#
#        ...                 91            92            93            94  \
# 0      ...       6.001508e+03  6.001508e+03  6.001508e+03  6.001508e+03
# 1      ...       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 2      ...       6.115424e+03  6.112404e+03  6.110286e+03  6.110285e+03
# 3      ...      -5.105495e-08 -5.105374e-08 -5.105399e-08 -5.105163e-08
# 4      ...       1.201656e+04  1.201656e+04  1.201656e+04  1.201656e+04
#
#              95            96            97            98            99  \
# ...

# %%
# recode quantile values
# df.loc[df['quantile'] == "1st quantile", 'quantile'] = 1
# df.loc[df['quantile'] == "2nd quantile", 'quantile'] = 2
# df.loc[df['quantile'] == "3rd quantile", 'quantile'] = 3
# df.loc[df['quantile'] == "4th quantile", 'quantile'] = 4
# df.loc[df['quantile'] == "5th quantile", 'quantile'] = 5

# %%
# get columns with dollar amounts to round
# cols = []
# for x in range(22, 101):
#     value = x
#     cols.append(str(x))
# print(cols)

# %%
# round selected columns' values to nearest whole number
# df[cols] = df[cols].round()

# %%
df.head()
# Out:
#    quartile  Age     variable type  amount  risk  18  19  20  21  \
# 0         1   22       Income  ISA    5000     3 NaN NaN NaN NaN
# 1         1   22      Payment  ISA    5000     3 NaN NaN NaN NaN
# 2         1   22  Consumption  ISA    5000     3 NaN NaN NaN NaN
# 3         1   22      Utility  ISA    5000     3 NaN NaN NaN NaN
# 4         2   22       Income  ISA    5000     3 NaN NaN NaN NaN
#
#        ...                 91            92            93            94  \
# 0      ...       6.001508e+03  6.001508e+03  6.001508e+03  6.001508e+03
# 1      ...       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 2      ...       6.115424e+03  6.112404e+03  6.110286e+03  6.110285e+03
# 3      ...      -5.105495e-08 -5.105374e-08 -5.105399e-08 -5.105163e-08
# 4      ...       1.201656e+04  1.201656e+04  1.201656e+04  1.201656e+04
#
#              95            96            97            98            99  \
# ...

# %%
df['22'].dtype
# Out:
# dtype('float64')

# %%
# see what values there are to filter rows by
quantiles = df['quartile'].unique()
variables = df['variable'].unique()
amounts = df['amount'].unique()
types = df['type'].unique()
risks = df['risk'].unique()
print("Quartiles: " + str(quantiles))
print("\t")
print("Variables: " + str(variables))
print("\t")
print("Amount: " + str(amounts))
print("\t")
print("Type: " + str(types))
print("\t")
print("Risk: " + str(risks))
# Out:
# Quartiles: [1 2 3 4]
#
# Variables: ['Income' 'Payment' 'Consumption' 'Utility']
#
# Amount: [ 5000     0 70000 30000]
#
# Type: ['ISA' 'cg' 'ISA-Purdue' 'debt' 'IDR' 'hsg']
#
# Risk: [3 1 2 4]

# %%
df.to_csv('data_vis.csv',index=False)
